# %%
import healpy as hp
import matplotlib.pyplot as plt
import sys
from tqdm import tqdm
sys.path.append('../')

# %%
# %load_ext autoreload
# %autoreload 2
from cobi.simulation import CMB

# %%
dir = '/global/cfs/cdirs/sobs/cosmic_birefringence/v0'

# %%
cmb = CMB(dir,nside=2048,model='iso',mass=6.4,lensing=True)
# Out:
# CMB : INFO - Loading CMB power spectra from file
# CMB : INFO - Isotropic cosmic birefringence model selected
# CMB : INFO - Time dependent component with axion mass = 6.4 * 10^-28 eV selected

# %%
plt.plot(cmb.__td_eb__())

# %%
spectra = cmb.get_cb_lensed_spectra(0.35,dl=False)

# %%
elm,blm = hp.map2alm_spin([q,u],2)

# %%
plt.loglog(hp.alm2cl(elm))
plt.loglog(spectra['ee'])
plt.loglog(hp.alm2cl(blm))
plt.loglog(spectra['bb'])
plt.loglog(hp.alm2cl(elm,blm))
plt.loglog(spectra['eb'])
plt.xlim(2,6000)
# Out:
# (2, 6000)
