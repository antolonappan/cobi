# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.append('../')
import healpy as hp
import os

# %%
libdir = '/global/cfs/cdirs/sobs/cosmic_birefringence/sims/LAT_anisotropic_noise_carlos'

# %%
simdir = os.path.join(libdir, 'Set1')

# %%
cmbfname = lambda idx: os.path.join(simdir, f"CMB_hilc_LAT_d10s5_Set1_seed{idx:04d}.fits")

# %%
Nell = np.load(os.path.join(libdir,'Nell_fullLAT_5.0_deg_gal_with-srcs-galplane80_spin2.npy'))

# %%
plt.figure(figsize=(3,3))
plt.loglog(Nell[0][0])
plt.loglog(Nell[0][3])

# %%
emap = hp.read_map(cmbfname(0),field=0)
bmap = hp.read_map(cmbfname(0),field=1)

# %%
plt.loglog(hp.anafast(emap),label='E')
plt.loglog(hp.anafast(bmap),label='B')

# %%
hp.mollview(hp.read_map(cmbfname(0),field=1),norm='hist',title='CMB')

# %%
nside = 2048
nlevp = 4
pixar = hp.nside2pixarea(nside, degrees=True) * 60**2
inv_p = pixar / nlevp ** 2
print(f"inv_p = {inv_p}")
# Out:
# inv_p = 0.18441510759034427

# %%
nl = np.ones(3*nside)* np.radians(nlevp/60)**2

# %%
w = hp.pixwin(nside, pol=True)

# %%
l = np.arange(3*nside)

# %%
ww =w[1]

# %%
var = np.sum((2 * l + 1) / (4 * np.pi) * nl * ww**2)

# %%
1/var
# Out:
# 0.36642690970625663
